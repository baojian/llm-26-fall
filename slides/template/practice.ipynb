# %% [markdown]
# # Lecture {{NUMBER}}: {{TITLE}}
#
# Companion exercises in slide order.

# %% [markdown]
# ## E01
#
# REPLACE: Copy the exercise prompt and expected output from the slide.

# %%
# REPLACE: Add a small runnable starter cell.
